# %%
import numpy as np
from scipy.io import loadmat

# Load the .mat file
for i in [num for num in range(48, 66)]:
    mat = loadmat(f'data/B1654run{i}.mat')

    # Clean out metadata
    data = {k: v for k, v in mat.items() if not k.startswith('__')}

    # Try to find and print tire info
    tire_nd = data.get('TIRFILE', ['Unknown Tire'])[0]
    if isinstance(tire_name, np.ndarray):
        tire_name = tire_nd.item()  # extract string from array
    print(f"🛞 Tire: {tire_name}")
    print(data['tireid'])

    # Flatten and ensure all values are positive (since forces are often negative for direction)
    FZ = np.abs(data['FZ'].flatten())  # Normal load (N)
    FX = np.abs(data['FX'].flatten())  # Longitudinal force (N)

    # Compute friction coefficient
    mu = FX / FZ

    # Find peak mu and corresponding values
    max_index = np.argmax(mu)
    mu_peak = mu[max_index]
    fz_peak = FZ[max_index]
    fx_peak = FX[max_index]

    # Output results
    print(f"🔍 Peak Longitudinal μ = {mu_peak:.3f}")
    print(f"🔩 Occurs at Load (FZ) = {fz_peak:.1f} N")
    print(f"🚀 Corresponding Longitudinal Force (FX) = {fx_peak:.1f} N")
# Out:
# 🛞 Tire: Unknown Tire
# ['Hoosier 20.5 x 6.0 13 R25B A2500 (Item 43127), 6 inch rim']
# 🔍 Peak Longitudinal μ = 1.570
# 🔩 Occurs at Load (FZ) = 181.9 N
# 🚀 Corresponding Longitudinal Force (FX) = 285.5 N
# 🛞 Tire: Unknown Tire
# ['Hoosier 20.5 x 6.0 13 R25B A2500 (Item 43127), 6 inch rim']
# 🔍 Peak Longitudinal μ = 3.513
# 🔩 Occurs at Load (FZ) = 157.9 N
# 🚀 Corresponding Longitudinal Force (FX) = 554.8 N
# 🛞 Tire: Unknown Tire
# ['Hoosier 20.5 x 6.0 13 R25B A2500 (Item 43127), 6 inch rim']
# 🔍 Peak Longitudinal μ = 5.924
# 🔩 Occurs at Load (FZ) = 143.8 N
# 🚀 Corresponding Longitudinal Force (FX) = 851.7 N
# 🛞 Tire: Unknown Tire
# ['Hoosier 20.5 x 6.0 13 R25B A2500 (Item 43127), 7 inch rim']
# 🔍 Peak Longitudinal μ = 3.197
# 🔩 Occurs at Load (FZ) = 110.9 N
# 🚀 Corresponding Longitudinal Force (FX) = 354.5 N
# 🛞 Tire: Unknown Tire
# ['Hoosier 20.5 x 6.0 13 R25B A2500 (Item 43127), 7 inch rim']
# 🔍 Peak Longitudinal μ = 5.117
# 🔩 Occurs at Load (FZ) = 133.2 N
# 🚀 Corresponding Longitudinal Force (FX) = 681.3 N
# 🛞 Tire: Unknown Tire
# ['Hoosier 20.5 x 6.0 13 R25B A2500 (Item 43127), 7 inch rim']
# 🔍 Peak Longitudinal μ = 6.491
# 🔩 Occurs at Load (FZ) = 138.0 N
# 🚀 Corresponding Longitudinal Force (FX) = 895.8 N
# 🛞 Tire: Unknown Tire
# ['Hoosier 20.5 x 7.0 13 R25B A2500 (Item 43163), 7 inch rim']
# 🔍 Peak Longitudinal μ = 3.226
# 🔩 Occurs at Load (FZ) = 142.1 N
# 🚀 Corresponding Longitudinal Force (FX) = 458.3 N
# 🛞 Tire: Unknown Tire
# ['Hoosier 20.5 x 7.0 13 R25B A2500 (Item 43163), 7 inch rim']
# 🔍 Peak Longitudinal μ = 5.335
# 🔩 Occurs at Load (FZ) = 136.7 N
# 🚀 Corresponding Longitudinal Force (FX) = 729.4 N
# 🛞 Tire: Unknown Tire
# ['Hoosier 20.5 x 7.0 13 R25B A2500 (Item 43163), 7 inch rim']
# 🔍 Peak Longitudinal μ = 3.673
# 🔩 Occurs at Load (FZ) = 134.7 N
# 🚀 Corresponding Longitudinal Force (FX) = 494.7 N
# 🛞 Tire: Unknown Tire
# ['Hoosier 20.5 x 7.0 13 R25B A2500 (Item 43163), 8 inch rim']
# 🔍 Peak Longitudinal μ = 2.376
# 🔩 Occurs at Load (FZ) = 100.5 N
# 🚀 Corresponding Longitudinal Force (FX) = 238.7 N
# 🛞 Tire: Unknown Tire
# ['Hoosier 20.5 x 7.0 13 R25B A2500 (Item 43163), 8 inch rim']
# 🔍 Peak Longitudinal μ = 6.359
# 🔩 Occurs at Load (FZ) = 101.0 N
# 🚀 Corresponding Longitudinal Force (FX) = 642.5 N
# 🛞 Tire: Unknown Tire
# ['Hoosier 20.5 x 7.0 13 R25B A2500 (Item 43163), 8 inch rim']
# 🔍 Peak Longitudinal μ = 7.902
# 🔩 Occurs at Load (FZ) = 103.1 N
# 🚀 Corresponding Longitudinal Force (FX) = 814.6 N
# 🛞 Tire: Unknown Tire
# ['Continental 205/510R13 (4914), 7 inch rim']
# 🔍 Peak Longitudinal μ = 2.464
# 🔩 Occurs at Load (FZ) = 151.4 N
# 🚀 Corresponding Longitudinal Force (FX) = 373.1 N
# 🛞 Tire: Unknown Tire
# ['Continental 205/510R13 (4914), 7 inch rim']
# 🔍 Peak Longitudinal μ = 2.928
# 🔩 Occurs at Load (FZ) = 621.5 N
# 🚀 Corresponding Longitudinal Force (FX) = 1819.5 N
# 🛞 Tire: Unknown Tire
# ['Continental 205/510R13 (4914), 7 inch rim']
# 🔍 Peak Longitudinal μ = 5.691
# 🔩 Occurs at Load (FZ) = 156.1 N
# 🚀 Corresponding Longitudinal Force (FX) = 888.3 N
# 🛞 Tire: Unknown Tire
# ['Continental 205/510R13 (4914), 8 inch rim']
# 🔍 Peak Longitudinal μ = 2.514
# 🔩 Occurs at Load (FZ) = 140.2 N
# 🚀 Corresponding Longitudinal Force (FX) = 352.6 N
# 🛞 Tire: Unknown Tire
# ['Continental 205/510R13 (4914), 8 inch rim']
# 🔍 Peak Longitudinal μ = 4.285
# 🔩 Occurs at Load (FZ) = 136.6 N
# 🚀 Corresponding Longitudinal Force (FX) = 585.4 N
# 🛞 Tire: Unknown Tire
# ['Continental 205/510R13 (4914), 8 inch rim']
# 🔍 Peak Longitudinal μ = 3.711
# 🔩 Occurs at Load (FZ) = 168.4 N
# 🚀 Corresponding Longitudinal Force (FX) = 624.7 N
